# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanapatil01/AgriPredict-Crop_Prediction-/blob/main/house_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,root_mean_squared_error,mean_absolute_error,r2_score

# %%
df = pd.read_csv("/content/House Price Prediction Dataset.csv")

# %%
df.isnull().sum()
# Out:
# Id           0
# Area         0
# Bedrooms     0
# Bathrooms    0
# Floors       0
# YearBuilt    0
# Location     0
# Condition    0
# Garage       0
# Price        0
# dtype: int64

# %%
#df.fillna(df.mean(), inplace=True)

# %%
X = df[['Area','Bedrooms','Bathrooms','Floors']]
y = df['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(X_test)

# %%
print(mean_squared_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(root_mean_squared_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# 77275973847.97093
# 240683.76763003887
# 277985.56409995636
# -0.005067812901829782

# %%
new_house = [[2000, 3, 2, 2]]

# %%
predicted_price = model.predict(new_house)

print("Predicted House Price:", predicted_price[0])
# Out:
# Predicted House Price: 537468.5817549939
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pickle as pickle

# %%
pickle.dump(model,open('model.pkl','wb'))

# %%
pickle.load(open('model.pkl','rb'))
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import Ridge,Lasso #l2 regularization

# %%
clf = Ridge(alpha=1.0)

# %%
clf.fit(X_train,y_train)
# Out:
# Ridge()

# %%
pred=clf.predict(X_test)

# %%
print(mean_squared_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(root_mean_squared_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# 77275267745.1744
# 240683.05062725506
# 277984.29406204657
# -0.005058629178117835

# %%
new_house = [[2000, 3, 2, 2]]
predicted_price = clf.predict(new_house)

print("Predicted House Price:", predicted_price[0])
# Out:
# Predicted House Price: 537468.072956145
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(

# %%
ls=Lasso(alpha=1.0)

# %%
ls.fit(X_train,y_train)
# Out:
# Lasso()

# %%
pred=ls.predict(X_test)

# %%
print(mean_squared_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(root_mean_squared_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# 77275946877.66348
# 240683.78765362463
# 277985.5155896859
# -0.00506746212025333

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor(criterion='squared_error', splitter='best', max_depth=None, min_samples_split=2)

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
predict=dt.predict(X_test)

# %%
print(mean_squared_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(root_mean_squared_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# 77275946877.66348
# 240683.78765362463
# 277985.5155896859
# -0.00506746212025333

# %%
new_house = [[2000, 3, 2, 2]]
predicted_price =dt.predict(new_house)

print("Predicted House Price:", predicted_price[0])
# Out:
# Predicted House Price: 286109.0
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor(n_estimators=100, criterion='squared_error', max_depth=None)

# %%
rf=rf.fit(X_train,y_train)

# %%
pred=rf.predict(X_test)

# %%
print(mean_squared_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(root_mean_squared_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# 92386667543.49872
# 259711.76027017855
# 303951.7519993901
# -0.20160072096808457

# %%
new_house = [[2000, 3, 2, 2]]
predicted_price = rf.predict(new_house)

print("Predicted House Price:", predicted_price[0])
# Out:
# Predicted House Price: 429198.2
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gb=GradientBoostingRegressor(loss='squared_error', learning_rate=0.1, n_estimators=100,min_samples_split=2,max_depth=3)

# %%
gb.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
pred=gb.predict(X_test)

# %%
print(mean_squared_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(root_mean_squared_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# 78777264790.87732
# 240860.49125013995
# 280672.8786165085
# -0.024593923403973594

# %%
new_house = [[2000, 3, 2, 2]]
predicted_price = gb.predict(new_house)

print("Predicted House Price:", predicted_price[0])
# Out:
# Predicted House Price: 510115.34183109045
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(

# %%
from xgboost import XGBRegressor

# %%
xb=XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=3)

# %%
xb.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
pred=xb.predict(X_test)

# %%
print(mean_squared_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(root_mean_squared_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# 77675184128.0
# 240394.078125
# 278702.6875
# -0.01025998592376709

# %%
new_house = [[2000, 3, 2, 2]]
predicted_price = xb.predict(new_house)

print("Predicted House Price:", predicted_price[0])
# Out:
# Predicted House Price: 510154.12

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    "n_estimators": [100, 200],
    "max_depth": [3, 5, 7],
    "learning_rate": [0.05, 0.1],
    "subsample": [0.8, 1],
    "colsample_bytree": [0.8, 1]
}

# %%
grid = GridSearchCV(
    estimator=xb,
    param_grid=param_grid,
    cv=3,
    scoring="r2",

)

grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=3, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
# ...

# %%
print("Best Parameters:", grid.best_params_)
# Out:
# Best Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1}

# %%
xb=XGBRegressor( n_estimators= 100,learning_rate= 0.05, max_depth= 3, subsample= 1)

# %%
xb.fit(X_train,y_train)
pred=xb.predict(X_test)

# %%
print(mean_squared_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(root_mean_squared_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# 76116467712.0
# 238235.296875
# 275892.125
# 0.010013043880462646

# %%
new_house = [[2000, 3, 2, 2]]
predicted_price = xb.predict(new_house)

print("Predicted House Price:", predicted_price[0])
# Out:
# Predicted House Price: 510154.12
